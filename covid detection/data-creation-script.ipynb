# %%
import os
import pandas as pd
import shutil
import random

# %%
data = pd.read_csv('metadata.csv')
data.head()
# Out:
#   patientid  offset sex   age                   finding RT_PCR_positive  \
# 0         2     0.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 1         2     3.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 2         2     5.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 3         2     6.0   M  65.0  Pneumonia/Viral/COVID-19               Y
# 4         4     0.0   F  52.0  Pneumonia/Viral/COVID-19               Y
#
#   survival intubated intubation_present went_icu  ...              date  \
# 0        Y         N                  N        N  ...  January 22, 2020
# 1        Y         N                  N        N  ...  January 25, 2020
# 2        Y         N                  N        N  ...  January 27, 2020
# 3        Y         N                  N        N  ...  January 28, 2020
# 4      NaN         N                  N        N  ...  January 25, 2020
#
#                                             location  folder  \
# ...

# %%
covid_data = list(data[(data['finding']=='Pneumonia/Viral/COVID-19') & (data['view']=='PA')]['filename'])

# %%
for i in range(len(covid_data)):
    shutil.copy2('images/'+covid_data[i],'COVID/'+str(i)+'.jpg')

# %%
normal_data = os.listdir('../NORMAL')
random.shuffle(normal_data)
for i in range(len(covid_data)):
    shutil.copy2('NORMAL/'+normal_data[i],'norm/'+str(i)+'.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-baacc5506bfe> in <module>
#       2 random.shuffle(normal_data)
#       3 for i in range(len(normal_data)):
# ----> 4     shutil.copy2('NORMAL/'+normal_data[i],'norm/'+str(i)+'.jpg')
#
# C:\ProgramData\Anaconda3\lib\shutil.py in copy2(src, dst, follow_symlinks)
#     255     if os.path.isdir(dst):
#     256         dst = os.path.join(dst, os.path.basename(src))
# --> 257     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     258     copystat(src, dst, follow_symlinks=follow_symlinks)
#     259     return dst
#
# C:\ProgramData\Anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     118         os.symlink(os.readlink(src), dst)
#     119     else:
# --> 120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
# ...
